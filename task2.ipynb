# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Month', y='Sales', data=df)
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(df['Month'], df['Profit'], marker='o')
plt.title('Monthly Profit Trend')
plt.xlabel('Month')
plt.ylabel('Profit')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df['Sales'], labels=df['Month'], autopct='%1.1f%%')
plt.title('Sales Contribution by Month')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Customers'], bins=5)
plt.title('Customer Distribution')
plt.xlabel('Number of Customers')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='Customers', y='Sales', data=df, s=100)
plt.title('Customers vs Sales')
plt.xlabel('Customers')
plt.ylabel('Sales')
plt.show()

# %%
import pandas as pd

data = {
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Sales': [120, 150, 170, 160, 180, 210],
    'Profit': [20, 25, 30, 28, 35, 40],
    'Customers': [30, 45, 50, 48, 60, 70]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Month  Sales  Profit  Customers
# 0   Jan    120      20         30
# 1   Feb    150      25         45
# 2   Mar    170      30         50
# 3   Apr    160      28         48
# 4   May    180      35         60
# 5   Jun    210      40         70
